# %%
import pandas as pd
import yfinance

# %%
appleInfo = yfinance.Ticker("AAPL")

# %%
print("Company Sector : ", appleInfo.info['sector'])
print("Price Earnings Ratio : ", appleInfo.info['trailingPE'])
print("Company Beta : ", appleInfo.info['beta'])
# Out:
# Company Sector :  Technology
# Price Earnings Ratio :  30.28013
#  Company Beta :  1.29

# %%
aaplHisoricalPrices = appleInfo.history(period="max")

# %%
aaplHisoricalPrices.head(10)
# Out:
#                                Open      High       Low     Close     Volume  \
# Date
# 1980-12-12 00:00:00-05:00  0.099319  0.099750  0.099319  0.099319  469033600
# 1980-12-15 00:00:00-05:00  0.094569  0.094569  0.094137  0.094137  175884800
# 1980-12-16 00:00:00-05:00  0.087659  0.087659  0.087228  0.087228  105728000
# 1980-12-17 00:00:00-05:00  0.089387  0.089818  0.089387  0.089387   86441600
# 1980-12-18 00:00:00-05:00  0.091978  0.092410  0.091978  0.091978   73449600
# 1980-12-19 00:00:00-05:00  0.097592  0.098023  0.097592  0.097592   48630400
# 1980-12-22 00:00:00-05:00  0.102341  0.102774  0.102341  0.102341   37363200
# 1980-12-23 00:00:00-05:00  0.106660  0.107092  0.106660  0.106660   46950400
# 1980-12-24 00:00:00-05:00  0.112273  0.112705  0.112273  0.112273   48003200
# 1980-12-26 00:00:00-05:00  0.122637  0.123069  0.122637  0.122637   55574400
#
#                            Dividends  Stock Splits
# Date
# 1980-12-12 00:00:00-05:00        0.0           0.0
# ...
